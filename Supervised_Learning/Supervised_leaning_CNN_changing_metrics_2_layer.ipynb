# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
experiment_name = "CNN_2_layer"

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pandas as pd
import os
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

# %%
batch_size = 50
img_height = 224
img_width = 224

# %%
ushapes = r"G:/My Drive/HARP_DATASET/dataset_supervised/square_images_size224_cleaned/UShape"
no_ushapes = r"G:/My Drive/HARP_DATASET/dataset_supervised/square_images_size224_cleaned/NoUshape"

# %%
def extract_spectrograms(path):
  os.chdir(path)
  spectrograms = []

  with os.scandir(path) as files:
    for file in files:
      if file.name.endswith('.png'):
        spectrograms.append(file.path)
  return spectrograms

ushapes_spectrograms = extract_spectrograms(ushapes)
all_spectrograms = extract_spectrograms(no_ushapes)



print(len(ushapes_spectrograms), len(all_spectrograms))
no_ushape_spectrograms = [spectrogram_without_ushape for spectrogram_without_ushape in all_spectrograms if spectrogram_without_ushape not in ushapes_spectrograms]
# Out:
# 168 3822

# %%
def fill_df_with_label(spectrograms, label):
  new_df =  pd.DataFrame()
  new_df['filename'] = spectrograms
  new_df['label'] = [label] * len(spectrograms)

  return new_df


dataframe_ushape = fill_df_with_label(ushapes_spectrograms, "ushape")
dataframe_noshape = fill_df_with_label(no_ushape_spectrograms, "noshape")

df_train_ushape, df_rest_ushape = train_test_split(dataframe_ushape, random_state = 101, train_size=110)
df_train_no_shape, df_rest_no_shape = train_test_split(dataframe_noshape, random_state = 101, train_size=110)

df_val_ushape, df_test_ushape = train_test_split(df_rest_ushape, random_state = 101, train_size=55)
df_val_no_ushape, df_test_no_shape = train_test_split(df_rest_no_shape, random_state = 101, train_size=55)

df_train = df_train_ushape.append(df_train_no_shape)
df_train = df_train.sample(frac=1)

df_val = df_val_ushape.append(df_val_no_ushape)
df_val = df_val.sample(frac=1)

# %%
print(len(df_train.loc[df_train["label"] == "ushape"]))
print(len(df_val.loc[df_val["label"] == "ushape"]))
# Out:
# 110
# 55

# %%
import scipy 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create the ImageDataGenerator object
train_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
)

val_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
) 

# Generate batches and augment the images
train_generator = train_datagen.flow_from_dataframe(
    df_train,
    # directory='harp/training/',
    x_col='filename',
    y_col='label',
    class_mode='binary',
    target_size=(224, 224),
)

val_generator = train_datagen.flow_from_dataframe(
    df_val,
    # directory='harp/validation/',
    x_col='filename',
    y_col='label',
    class_mode='binary',
    target_size=(224, 224),
)
# Out:
# Found 220 validated image filenames belonging to 2 classes.
# Found 110 validated image filenames belonging to 2 classes.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
#num_classes = len(class_names)
model = Sequential([
  #data_augmentation,
  layers.Input(shape=(224, 224, 3)),
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 16)     0
#  )
#
#  dropout (Dropout)           (None, 112, 112, 16)      0
#
#  flatten (Flatten)           (None, 200704)            0
#
#  dense (Dense)               (None, 128)               25690240
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 25,690,817
# Trainable params: 25,690,817
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit_generator(generator=
  train_generator,
  validation_data=val_generator,
  epochs=epochs
)
# Out:
# c:\y\HARP_3_7\venv\lib\site-packages\ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# c:\y\HARP_3_7\venv\lib\site-packages\keras\preprocessing\image.py:1864: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   "This ImageDataGenerator specifies "
# c:\y\HARP_3_7\venv\lib\site-packages\keras\preprocessing\image.py:1874: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   "This ImageDataGenerator specifies "
# Epoch 1/50
# 7/7 [==============================] - 35s 3s/step - loss: 4.0461 - tp: 65.0000 - fp: 60.0000 - tn: 50.0000 - fn: 45.0000 - accuracy: 0.5227 - precision: 0.5200 - recall: 0.5909 - auc: 0.5194 - prc: 0.5162 - val_loss: 1.9704 - val_tp: 55.0000 - val_fp: 55.0000 - val_tn: 0.0000e+00 - val_fn: 0.0000e+00 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000 - val_auc: 0.6136 - val_prc: 0.5705
# Epoch 2/50
# 7/7 [==============================] - 21s 3s/step - loss: 1.0029 - tp: 54.0000 - fp: 42.0000 - tn: 68.0000 - fn: 56.0000 - accuracy: 0.5545 - precision: 0.5625 - recall: 0.4909 - auc: 0.6252 - prc: 0.5744 - val_loss: 0.7974 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 55.0000 - val_fn: 53.0000 - val_accuracy: 0.5182 - val_precision: 1.0000 - val_recall: 0.0364 - val_auc: 0.7998 - val_prc: 0.8012
# Epoch 3/50
# 7/7 [==============================] - 24s 4s/step - loss: 0.6101 - tp: 63.0000 - fp: 26.0000 - tn: 84.0000 - fn: 47.0000 - accuracy: 0.6682 - precision: 0.7079 - recall: 0.5727 - auc: 0.7407 - prc: 0.7041 - val_loss: 0.6310 - val_tp: 54.0000 - val_fp: 43.0000 - val_tn: 12.0000 - val_fn: 1.0000 - val_accuracy: 0.6000 - val_precision: 0.5567 - val_recall: 0.9818 - val_auc: 0.8367 - val_prc: 0.8360
# Epoch 4/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.6225 - tp: 87.0000 - fp: 52.0000 - tn: 58.0000 - fn: 23.0000 - accuracy: 0.6591 - precision: 0.6259 - recall: 0.7909 - auc: 0.6993 - prc: 0.6744 - val_loss: 0.5622 - val_tp: 28.0000 - val_fp: 5.0000 - val_tn: 50.0000 - val_fn: 27.0000 - val_accuracy: 0.7091 - val_precision: 0.8485 - val_recall: 0.5091 - val_auc: 0.8511 - val_prc: 0.8614
# Epoch 5/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.6192 - tp: 76.0000 - fp: 41.0000 - tn: 69.0000 - fn: 34.0000 - accuracy: 0.6591 - precision: 0.6496 - recall: 0.6909 - auc: 0.7122 - prc: 0.6897 - val_loss: 0.5694 - val_tp: 50.0000 - val_fp: 29.0000 - val_tn: 26.0000 - val_fn: 5.0000 - val_accuracy: 0.6909 - val_precision: 0.6329 - val_recall: 0.9091 - val_auc: 0.8187 - val_prc: 0.8262
# Epoch 6/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.5340 - tp: 85.0000 - fp: 37.0000 - tn: 73.0000 - fn: 25.0000 - accuracy: 0.7182 - precision: 0.6967 - recall: 0.7727 - auc: 0.8110 - prc: 0.7775 - val_loss: 0.5073 - val_tp: 37.0000 - val_fp: 5.0000 - val_tn: 50.0000 - val_fn: 18.0000 - val_accuracy: 0.7909 - val_precision: 0.8810 - val_recall: 0.6727 - val_auc: 0.8843 - val_prc: 0.9009
# Epoch 7/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.5517 - tp: 87.0000 - fp: 40.0000 - tn: 70.0000 - fn: 23.0000 - accuracy: 0.7136 - precision: 0.6850 - recall: 0.7909 - auc: 0.7796 - prc: 0.7435 - val_loss: 0.5296 - val_tp: 43.0000 - val_fp: 18.0000 - val_tn: 37.0000 - val_fn: 12.0000 - val_accuracy: 0.7273 - val_precision: 0.7049 - val_recall: 0.7818 - val_auc: 0.8091 - val_prc: 0.7841
# Epoch 8/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.5806 - tp: 82.0000 - fp: 42.0000 - tn: 68.0000 - fn: 28.0000 - accuracy: 0.6818 - precision: 0.6613 - recall: 0.7455 - auc: 0.7595 - prc: 0.7567 - val_loss: 0.5192 - val_tp: 49.0000 - val_fp: 24.0000 - val_tn: 31.0000 - val_fn: 6.0000 - val_accuracy: 0.7273 - val_precision: 0.6712 - val_recall: 0.8909 - val_auc: 0.8426 - val_prc: 0.8584
# Epoch 9/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.5613 - tp: 89.0000 - fp: 50.0000 - tn: 60.0000 - fn: 21.0000 - accuracy: 0.6773 - precision: 0.6403 - recall: 0.8091 - auc: 0.7765 - prc: 0.7665 - val_loss: 0.5250 - val_tp: 38.0000 - val_fp: 12.0000 - val_tn: 43.0000 - val_fn: 17.0000 - val_accuracy: 0.7364 - val_precision: 0.7600 - val_recall: 0.6909 - val_auc: 0.8230 - val_prc: 0.8490
# Epoch 10/50
# 7/7 [==============================] - 36s 5s/step - loss: 0.5270 - tp: 86.0000 - fp: 35.0000 - tn: 75.0000 - fn: 24.0000 - accuracy: 0.7318 - precision: 0.7107 - recall: 0.7818 - auc: 0.8184 - prc: 0.8171 - val_loss: 0.4841 - val_tp: 43.0000 - val_fp: 13.0000 - val_tn: 42.0000 - val_fn: 12.0000 - val_accuracy: 0.7727 - val_precision: 0.7679 - val_recall: 0.7818 - val_auc: 0.8607 - val_prc: 0.8534
# Epoch 11/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.5376 - tp: 77.0000 - fp: 34.0000 - tn: 76.0000 - fn: 33.0000 - accuracy: 0.6955 - precision: 0.6937 - recall: 0.7000 - auc: 0.7960 - prc: 0.7919 - val_loss: 0.5051 - val_tp: 44.0000 - val_fp: 17.0000 - val_tn: 38.0000 - val_fn: 11.0000 - val_accuracy: 0.7455 - val_precision: 0.7213 - val_recall: 0.8000 - val_auc: 0.8405 - val_prc: 0.8550
# Epoch 12/50
# 7/7 [==============================] - 37s 6s/step - loss: 0.5268 - tp: 93.0000 - fp: 43.0000 - tn: 67.0000 - fn: 17.0000 - accuracy: 0.7273 - precision: 0.6838 - recall: 0.8455 - auc: 0.8141 - prc: 0.8176 - val_loss: 0.5137 - val_tp: 41.0000 - val_fp: 12.0000 - val_tn: 43.0000 - val_fn: 14.0000 - val_accuracy: 0.7636 - val_precision: 0.7736 - val_recall: 0.7455 - val_auc: 0.8291 - val_prc: 0.8420
# Epoch 13/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.5171 - tp: 80.0000 - fp: 28.0000 - tn: 82.0000 - fn: 30.0000 - accuracy: 0.7364 - precision: 0.7407 - recall: 0.7273 - auc: 0.8207 - prc: 0.8106 - val_loss: 0.5167 - val_tp: 42.0000 - val_fp: 13.0000 - val_tn: 42.0000 - val_fn: 13.0000 - val_accuracy: 0.7636 - val_precision: 0.7636 - val_recall: 0.7636 - val_auc: 0.8322 - val_prc: 0.8624
# Epoch 14/50
# 7/7 [==============================] - 31s 5s/step - loss: 0.5169 - tp: 78.0000 - fp: 25.0000 - tn: 85.0000 - fn: 32.0000 - accuracy: 0.7409 - precision: 0.7573 - recall: 0.7091 - auc: 0.8195 - prc: 0.8078 - val_loss: 0.4863 - val_tp: 50.0000 - val_fp: 20.0000 - val_tn: 35.0000 - val_fn: 5.0000 - val_accuracy: 0.7727 - val_precision: 0.7143 - val_recall: 0.9091 - val_auc: 0.8694 - val_prc: 0.8729
# Epoch 15/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.4997 - tp: 101.0000 - fp: 45.0000 - tn: 65.0000 - fn: 9.0000 - accuracy: 0.7545 - precision: 0.6918 - recall: 0.9182 - auc: 0.8551 - prc: 0.8512 - val_loss: 0.5380 - val_tp: 27.0000 - val_fp: 4.0000 - val_tn: 51.0000 - val_fn: 28.0000 - val_accuracy: 0.7091 - val_precision: 0.8710 - val_recall: 0.4909 - val_auc: 0.8602 - val_prc: 0.8745
# Epoch 16/50
# 7/7 [==============================] - 35s 5s/step - loss: 0.5383 - tp: 80.0000 - fp: 32.0000 - tn: 78.0000 - fn: 30.0000 - accuracy: 0.7182 - precision: 0.7143 - recall: 0.7273 - auc: 0.8013 - prc: 0.7697 - val_loss: 0.5473 - val_tp: 48.0000 - val_fp: 28.0000 - val_tn: 27.0000 - val_fn: 7.0000 - val_accuracy: 0.6818 - val_precision: 0.6316 - val_recall: 0.8727 - val_auc: 0.8093 - val_prc: 0.8193
# Epoch 17/50
# 7/7 [==============================] - 37s 6s/step - loss: 0.4916 - tp: 89.0000 - fp: 29.0000 - tn: 81.0000 - fn: 21.0000 - accuracy: 0.7727 - precision: 0.7542 - recall: 0.8091 - auc: 0.8396 - prc: 0.8252 - val_loss: 0.4769 - val_tp: 42.0000 - val_fp: 13.0000 - val_tn: 42.0000 - val_fn: 13.0000 - val_accuracy: 0.7636 - val_precision: 0.7636 - val_recall: 0.7636 - val_auc: 0.8597 - val_prc: 0.8646
# Epoch 18/50
# 7/7 [==============================] - 30s 5s/step - loss: 0.5029 - tp: 91.0000 - fp: 34.0000 - tn: 76.0000 - fn: 19.0000 - accuracy: 0.7591 - precision: 0.7280 - recall: 0.8273 - auc: 0.8367 - prc: 0.8281 - val_loss: 0.5205 - val_tp: 37.0000 - val_fp: 5.0000 - val_tn: 50.0000 - val_fn: 18.0000 - val_accuracy: 0.7909 - val_precision: 0.8810 - val_recall: 0.6727 - val_auc: 0.8526 - val_prc: 0.8736
# Epoch 19/50
# 7/7 [==============================] - 31s 5s/step - loss: 0.4886 - tp: 77.0000 - fp: 22.0000 - tn: 88.0000 - fn: 33.0000 - accuracy: 0.7500 - precision: 0.7778 - recall: 0.7000 - auc: 0.8440 - prc: 0.8293 - val_loss: 0.5364 - val_tp: 53.0000 - val_fp: 26.0000 - val_tn: 29.0000 - val_fn: 2.0000 - val_accuracy: 0.7455 - val_precision: 0.6709 - val_recall: 0.9636 - val_auc: 0.8349 - val_prc: 0.8143
# Epoch 20/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.5094 - tp: 89.0000 - fp: 38.0000 - tn: 72.0000 - fn: 21.0000 - accuracy: 0.7318 - precision: 0.7008 - recall: 0.8091 - auc: 0.8281 - prc: 0.8272 - val_loss: 0.5759 - val_tp: 26.0000 - val_fp: 4.0000 - val_tn: 51.0000 - val_fn: 29.0000 - val_accuracy: 0.7000 - val_precision: 0.8667 - val_recall: 0.4727 - val_auc: 0.8268 - val_prc: 0.8394
# Epoch 21/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.5480 - tp: 85.0000 - fp: 37.0000 - tn: 73.0000 - fn: 25.0000 - accuracy: 0.7182 - precision: 0.6967 - recall: 0.7727 - auc: 0.7993 - prc: 0.7936 - val_loss: 0.4958 - val_tp: 37.0000 - val_fp: 11.0000 - val_tn: 44.0000 - val_fn: 18.0000 - val_accuracy: 0.7364 - val_precision: 0.7708 - val_recall: 0.6727 - val_auc: 0.8516 - val_prc: 0.8553
# Epoch 22/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4920 - tp: 79.0000 - fp: 18.0000 - tn: 92.0000 - fn: 31.0000 - accuracy: 0.7773 - precision: 0.8144 - recall: 0.7182 - auc: 0.8495 - prc: 0.8485 - val_loss: 0.4795 - val_tp: 49.0000 - val_fp: 21.0000 - val_tn: 34.0000 - val_fn: 6.0000 - val_accuracy: 0.7545 - val_precision: 0.7000 - val_recall: 0.8909 - val_auc: 0.8678 - val_prc: 0.8544
# Epoch 23/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.5232 - tp: 91.0000 - fp: 37.0000 - tn: 73.0000 - fn: 19.0000 - accuracy: 0.7455 - precision: 0.7109 - recall: 0.8273 - auc: 0.8141 - prc: 0.7941 - val_loss: 0.5368 - val_tp: 36.0000 - val_fp: 9.0000 - val_tn: 46.0000 - val_fn: 19.0000 - val_accuracy: 0.7455 - val_precision: 0.8000 - val_recall: 0.6545 - val_auc: 0.8248 - val_prc: 0.8463
# Epoch 24/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4892 - tp: 87.0000 - fp: 25.0000 - tn: 85.0000 - fn: 23.0000 - accuracy: 0.7818 - precision: 0.7768 - recall: 0.7909 - auc: 0.8512 - prc: 0.8260 - val_loss: 0.5288 - val_tp: 44.0000 - val_fp: 15.0000 - val_tn: 40.0000 - val_fn: 11.0000 - val_accuracy: 0.7636 - val_precision: 0.7458 - val_recall: 0.8000 - val_auc: 0.8145 - val_prc: 0.8103
# Epoch 25/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.5391 - tp: 82.0000 - fp: 35.0000 - tn: 75.0000 - fn: 28.0000 - accuracy: 0.7136 - precision: 0.7009 - recall: 0.7455 - auc: 0.7993 - prc: 0.7901 - val_loss: 0.5375 - val_tp: 39.0000 - val_fp: 16.0000 - val_tn: 39.0000 - val_fn: 16.0000 - val_accuracy: 0.7091 - val_precision: 0.7091 - val_recall: 0.7091 - val_auc: 0.8018 - val_prc: 0.7941
# Epoch 26/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4667 - tp: 91.0000 - fp: 30.0000 - tn: 80.0000 - fn: 19.0000 - accuracy: 0.7773 - precision: 0.7521 - recall: 0.8273 - auc: 0.8593 - prc: 0.8436 - val_loss: 0.4985 - val_tp: 40.0000 - val_fp: 9.0000 - val_tn: 46.0000 - val_fn: 15.0000 - val_accuracy: 0.7818 - val_precision: 0.8163 - val_recall: 0.7273 - val_auc: 0.8615 - val_prc: 0.8800
# Epoch 27/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4680 - tp: 88.0000 - fp: 37.0000 - tn: 73.0000 - fn: 22.0000 - accuracy: 0.7318 - precision: 0.7040 - recall: 0.8000 - auc: 0.8512 - prc: 0.8524 - val_loss: 0.4972 - val_tp: 45.0000 - val_fp: 14.0000 - val_tn: 41.0000 - val_fn: 10.0000 - val_accuracy: 0.7818 - val_precision: 0.7627 - val_recall: 0.8182 - val_auc: 0.8469 - val_prc: 0.8312
# Epoch 28/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4847 - tp: 83.0000 - fp: 28.0000 - tn: 82.0000 - fn: 27.0000 - accuracy: 0.7500 - precision: 0.7477 - recall: 0.7545 - auc: 0.8410 - prc: 0.8261 - val_loss: 0.4371 - val_tp: 41.0000 - val_fp: 10.0000 - val_tn: 45.0000 - val_fn: 14.0000 - val_accuracy: 0.7818 - val_precision: 0.8039 - val_recall: 0.7455 - val_auc: 0.8845 - val_prc: 0.8952
# Epoch 29/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.4610 - tp: 93.0000 - fp: 30.0000 - tn: 80.0000 - fn: 17.0000 - accuracy: 0.7864 - precision: 0.7561 - recall: 0.8455 - auc: 0.8653 - prc: 0.8268 - val_loss: 0.5138 - val_tp: 34.0000 - val_fp: 8.0000 - val_tn: 47.0000 - val_fn: 21.0000 - val_accuracy: 0.7364 - val_precision: 0.8095 - val_recall: 0.6182 - val_auc: 0.8336 - val_prc: 0.8440
# Epoch 30/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4824 - tp: 87.0000 - fp: 27.0000 - tn: 83.0000 - fn: 23.0000 - accuracy: 0.7727 - precision: 0.7632 - recall: 0.7909 - auc: 0.8460 - prc: 0.8243 - val_loss: 0.4818 - val_tp: 40.0000 - val_fp: 11.0000 - val_tn: 44.0000 - val_fn: 15.0000 - val_accuracy: 0.7636 - val_precision: 0.7843 - val_recall: 0.7273 - val_auc: 0.8463 - val_prc: 0.8565
# Epoch 31/50
# 7/7 [==============================] - 31s 5s/step - loss: 0.4745 - tp: 86.0000 - fp: 31.0000 - tn: 79.0000 - fn: 24.0000 - accuracy: 0.7500 - precision: 0.7350 - recall: 0.7818 - auc: 0.8474 - prc: 0.8265 - val_loss: 0.4670 - val_tp: 47.0000 - val_fp: 18.0000 - val_tn: 37.0000 - val_fn: 8.0000 - val_accuracy: 0.7636 - val_precision: 0.7231 - val_recall: 0.8545 - val_auc: 0.8807 - val_prc: 0.8788
# Epoch 32/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4459 - tp: 91.0000 - fp: 24.0000 - tn: 86.0000 - fn: 19.0000 - accuracy: 0.8045 - precision: 0.7913 - recall: 0.8273 - auc: 0.8694 - prc: 0.8482 - val_loss: 0.4892 - val_tp: 41.0000 - val_fp: 16.0000 - val_tn: 39.0000 - val_fn: 14.0000 - val_accuracy: 0.7273 - val_precision: 0.7193 - val_recall: 0.7455 - val_auc: 0.8436 - val_prc: 0.8534
# Epoch 33/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4370 - tp: 86.0000 - fp: 22.0000 - tn: 88.0000 - fn: 24.0000 - accuracy: 0.7909 - precision: 0.7963 - recall: 0.7818 - auc: 0.8794 - prc: 0.8651 - val_loss: 0.4792 - val_tp: 41.0000 - val_fp: 18.0000 - val_tn: 37.0000 - val_fn: 14.0000 - val_accuracy: 0.7091 - val_precision: 0.6949 - val_recall: 0.7455 - val_auc: 0.8423 - val_prc: 0.8377
# Epoch 34/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4538 - tp: 93.0000 - fp: 30.0000 - tn: 80.0000 - fn: 17.0000 - accuracy: 0.7864 - precision: 0.7561 - recall: 0.8455 - auc: 0.8681 - prc: 0.8309 - val_loss: 0.4991 - val_tp: 32.0000 - val_fp: 5.0000 - val_tn: 50.0000 - val_fn: 23.0000 - val_accuracy: 0.7455 - val_precision: 0.8649 - val_recall: 0.5818 - val_auc: 0.8731 - val_prc: 0.8827
# Epoch 35/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4847 - tp: 86.0000 - fp: 30.0000 - tn: 80.0000 - fn: 24.0000 - accuracy: 0.7545 - precision: 0.7414 - recall: 0.7818 - auc: 0.8448 - prc: 0.8442 - val_loss: 0.4687 - val_tp: 48.0000 - val_fp: 17.0000 - val_tn: 38.0000 - val_fn: 7.0000 - val_accuracy: 0.7818 - val_precision: 0.7385 - val_recall: 0.8727 - val_auc: 0.8572 - val_prc: 0.8479
# Epoch 36/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4717 - tp: 76.0000 - fp: 20.0000 - tn: 90.0000 - fn: 34.0000 - accuracy: 0.7545 - precision: 0.7917 - recall: 0.6909 - auc: 0.8637 - prc: 0.8479 - val_loss: 0.6120 - val_tp: 50.0000 - val_fp: 30.0000 - val_tn: 25.0000 - val_fn: 5.0000 - val_accuracy: 0.6818 - val_precision: 0.6250 - val_recall: 0.9091 - val_auc: 0.7947 - val_prc: 0.7923
# Epoch 37/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.5181 - tp: 100.0000 - fp: 54.0000 - tn: 56.0000 - fn: 10.0000 - accuracy: 0.7091 - precision: 0.6494 - recall: 0.9091 - auc: 0.8467 - prc: 0.8463 - val_loss: 0.4878 - val_tp: 33.0000 - val_fp: 4.0000 - val_tn: 51.0000 - val_fn: 22.0000 - val_accuracy: 0.7636 - val_precision: 0.8919 - val_recall: 0.6000 - val_auc: 0.8899 - val_prc: 0.9008
# Epoch 38/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.5670 - tp: 69.0000 - fp: 25.0000 - tn: 85.0000 - fn: 41.0000 - accuracy: 0.7000 - precision: 0.7340 - recall: 0.6273 - auc: 0.7928 - prc: 0.7764 - val_loss: 0.5692 - val_tp: 50.0000 - val_fp: 29.0000 - val_tn: 26.0000 - val_fn: 5.0000 - val_accuracy: 0.6909 - val_precision: 0.6329 - val_recall: 0.9091 - val_auc: 0.8279 - val_prc: 0.8469
# Epoch 39/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.5277 - tp: 100.0000 - fp: 49.0000 - tn: 61.0000 - fn: 10.0000 - accuracy: 0.7318 - precision: 0.6711 - recall: 0.9091 - auc: 0.8342 - prc: 0.8355 - val_loss: 0.5017 - val_tp: 35.0000 - val_fp: 9.0000 - val_tn: 46.0000 - val_fn: 20.0000 - val_accuracy: 0.7364 - val_precision: 0.7955 - val_recall: 0.6364 - val_auc: 0.8660 - val_prc: 0.8694
# Epoch 40/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4896 - tp: 80.0000 - fp: 22.0000 - tn: 88.0000 - fn: 30.0000 - accuracy: 0.7636 - precision: 0.7843 - recall: 0.7273 - auc: 0.8545 - prc: 0.8421 - val_loss: 0.4998 - val_tp: 49.0000 - val_fp: 16.0000 - val_tn: 39.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7538 - val_recall: 0.8909 - val_auc: 0.8398 - val_prc: 0.8042
# Epoch 41/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4872 - tp: 98.0000 - fp: 39.0000 - tn: 71.0000 - fn: 12.0000 - accuracy: 0.7682 - precision: 0.7153 - recall: 0.8909 - auc: 0.8511 - prc: 0.8063 - val_loss: 0.4872 - val_tp: 43.0000 - val_fp: 13.0000 - val_tn: 42.0000 - val_fn: 12.0000 - val_accuracy: 0.7727 - val_precision: 0.7679 - val_recall: 0.7818 - val_auc: 0.8603 - val_prc: 0.8739
# Epoch 42/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.4283 - tp: 92.0000 - fp: 13.0000 - tn: 97.0000 - fn: 18.0000 - accuracy: 0.8591 - precision: 0.8762 - recall: 0.8364 - auc: 0.8912 - prc: 0.8798 - val_loss: 0.4535 - val_tp: 47.0000 - val_fp: 15.0000 - val_tn: 40.0000 - val_fn: 8.0000 - val_accuracy: 0.7909 - val_precision: 0.7581 - val_recall: 0.8545 - val_auc: 0.8691 - val_prc: 0.8746
# Epoch 43/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.4829 - tp: 92.0000 - fp: 39.0000 - tn: 71.0000 - fn: 18.0000 - accuracy: 0.7409 - precision: 0.7023 - recall: 0.8364 - auc: 0.8455 - prc: 0.8295 - val_loss: 0.4217 - val_tp: 42.0000 - val_fp: 6.0000 - val_tn: 49.0000 - val_fn: 13.0000 - val_accuracy: 0.8273 - val_precision: 0.8750 - val_recall: 0.7636 - val_auc: 0.9030 - val_prc: 0.8927
# Epoch 44/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4295 - tp: 84.0000 - fp: 21.0000 - tn: 89.0000 - fn: 26.0000 - accuracy: 0.7864 - precision: 0.8000 - recall: 0.7636 - auc: 0.8816 - prc: 0.8656 - val_loss: 0.4231 - val_tp: 48.0000 - val_fp: 15.0000 - val_tn: 40.0000 - val_fn: 7.0000 - val_accuracy: 0.8000 - val_precision: 0.7619 - val_recall: 0.8727 - val_auc: 0.8886 - val_prc: 0.8900
# Epoch 45/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4816 - tp: 97.0000 - fp: 36.0000 - tn: 74.0000 - fn: 13.0000 - accuracy: 0.7773 - precision: 0.7293 - recall: 0.8818 - auc: 0.8551 - prc: 0.8336 - val_loss: 0.5160 - val_tp: 35.0000 - val_fp: 8.0000 - val_tn: 47.0000 - val_fn: 20.0000 - val_accuracy: 0.7455 - val_precision: 0.8140 - val_recall: 0.6364 - val_auc: 0.8509 - val_prc: 0.8490
# Epoch 46/50
# 7/7 [==============================] - 32s 5s/step - loss: 0.4569 - tp: 80.0000 - fp: 16.0000 - tn: 94.0000 - fn: 30.0000 - accuracy: 0.7909 - precision: 0.8333 - recall: 0.7273 - auc: 0.8757 - prc: 0.8749 - val_loss: 0.4593 - val_tp: 50.0000 - val_fp: 22.0000 - val_tn: 33.0000 - val_fn: 5.0000 - val_accuracy: 0.7545 - val_precision: 0.6944 - val_recall: 0.9091 - val_auc: 0.8883 - val_prc: 0.8947
# Epoch 47/50
# 7/7 [==============================] - 27s 4s/step - loss: 0.4752 - tp: 96.0000 - fp: 40.0000 - tn: 70.0000 - fn: 14.0000 - accuracy: 0.7545 - precision: 0.7059 - recall: 0.8727 - auc: 0.8618 - prc: 0.8514 - val_loss: 0.5109 - val_tp: 35.0000 - val_fp: 3.0000 - val_tn: 52.0000 - val_fn: 20.0000 - val_accuracy: 0.7909 - val_precision: 0.9211 - val_recall: 0.6364 - val_auc: 0.8805 - val_prc: 0.8930
# Epoch 48/50
# 7/7 [==============================] - 34s 5s/step - loss: 0.4626 - tp: 87.0000 - fp: 29.0000 - tn: 81.0000 - fn: 23.0000 - accuracy: 0.7636 - precision: 0.7500 - recall: 0.7909 - auc: 0.8570 - prc: 0.8336 - val_loss: 0.5590 - val_tp: 51.0000 - val_fp: 27.0000 - val_tn: 28.0000 - val_fn: 4.0000 - val_accuracy: 0.7182 - val_precision: 0.6538 - val_recall: 0.9273 - val_auc: 0.8288 - val_prc: 0.7890
# Epoch 49/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4624 - tp: 85.0000 - fp: 26.0000 - tn: 84.0000 - fn: 25.0000 - accuracy: 0.7682 - precision: 0.7658 - recall: 0.7727 - auc: 0.8640 - prc: 0.8552 - val_loss: 0.4520 - val_tp: 41.0000 - val_fp: 10.0000 - val_tn: 45.0000 - val_fn: 14.0000 - val_accuracy: 0.7818 - val_precision: 0.8039 - val_recall: 0.7455 - val_auc: 0.8836 - val_prc: 0.9026
# Epoch 50/50
# 7/7 [==============================] - 33s 5s/step - loss: 0.4104 - tp: 98.0000 - fp: 29.0000 - tn: 81.0000 - fn: 12.0000 - accuracy: 0.8136 - precision: 0.7717 - recall: 0.8909 - auc: 0.8953 - prc: 0.8806 - val_loss: 0.4477 - val_tp: 44.0000 - val_fp: 10.0000 - val_tn: 45.0000 - val_fn: 11.0000 - val_accuracy: 0.8091 - val_precision: 0.8148 - val_recall: 0.8000 - val_auc: 0.8795 - val_prc: 0.8553

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('./cnn_50_epoch_more_metrics_balanced_dataset_'  + experiment_name)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./cnn_50_epoch_more_metrics_balanced_dataset\assets
# INFO:tensorflow:Assets written to: ./cnn_50_epoch_more_metrics_balanced_dataset\assets

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']



def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

plot_metrics(history)
