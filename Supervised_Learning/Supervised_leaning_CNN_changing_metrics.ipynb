# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pandas as pd
import os
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf

# %%
batch_size = 50
img_height = 224
img_width = 224

# %%
ushapes = r"G:/My Drive/HARP_DATASET/dataset_supervised/square_images_size224_cleaned/UShape"
no_ushapes = r"G:/My Drive/HARP_DATASET/dataset_supervised/square_images_size224_cleaned/NoUshape"

# %%
def extract_spectrograms(path):
  os.chdir(path)
  spectrograms = []

  with os.scandir(path) as files:
    for file in files:
      if file.name.endswith('.png'):
        spectrograms.append(file.path)
  return spectrograms

ushapes_spectrograms = extract_spectrograms(ushapes)
all_spectrograms = extract_spectrograms(no_ushapes)



print(len(ushapes_spectrograms), len(all_spectrograms))
no_ushape_spectrograms = [spectrogram_without_ushape for spectrogram_without_ushape in all_spectrograms if spectrogram_without_ushape not in ushapes_spectrograms]
# Out:
# 168 3822

# %%
def fill_df_with_label(spectrograms, label):
  new_df =  pd.DataFrame()
  new_df['filename'] = spectrograms
  new_df['label'] = [label] * len(spectrograms)

  return new_df


dataframe_total = fill_df_with_label(ushapes_spectrograms, "ushape").append(fill_df_with_label(no_ushape_spectrograms, "noshape"))


df_train, df_val = train_test_split(dataframe_total, random_state = 101, test_size=0.25)

# %%
import scipy 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create the ImageDataGenerator object
train_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
)

val_datagen = ImageDataGenerator(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
) 

# Generate batches and augment the images
train_generator = train_datagen.flow_from_dataframe(
    df_train,
    # directory='harp/training/',
    x_col='filename',
    y_col='label',
    class_mode='binary',
    target_size=(224, 224),
)

val_generator = train_datagen.flow_from_dataframe(
    df_val,
    # directory='harp/validation/',
    x_col='filename',
    y_col='label',
    class_mode='binary',
    target_size=(224, 224),
)
# Out:
# Found 2992 validated image filenames belonging to 2 classes.
# Found 998 validated image filenames belonging to 2 classes.

# %%
METRICS = [
      keras.metrics.TruePositives(name='tp'),
      keras.metrics.FalsePositives(name='fp'),
      keras.metrics.TrueNegatives(name='tn'),
      keras.metrics.FalseNegatives(name='fn'), 
      keras.metrics.BinaryAccuracy(name='accuracy'),
      keras.metrics.Precision(name='precision'),
      keras.metrics.Recall(name='recall'),
      keras.metrics.AUC(name='auc'),
      keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
#num_classes = len(class_names)
model = Sequential([
  #data_augmentation,
  layers.Input(shape=(224, 224, 3)),
  layers.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=METRICS)

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 224, 224, 3)       0
#
#  conv2d_6 (Conv2D)           (None, 224, 224, 16)      448
#
#  max_pooling2d_6 (MaxPooling  (None, 112, 112, 16)     0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 112, 112, 32)      4640
#
#  max_pooling2d_7 (MaxPooling  (None, 56, 56, 32)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 56, 56, 64)        18496
#
#  max_pooling2d_8 (MaxPooling  (None, 28, 28, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 28, 28, 64)        0
#
#  flatten_2 (Flatten)         (None, 50176)             0
#
#  dense_4 (Dense)             (None, 128)               6422656
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 6,446,369
# Trainable params: 6,446,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 50
history = model.fit_generator(generator=
  train_generator,
  validation_data=val_generator,
  epochs=epochs
)
# Out:
# c:\y\HARP_3_7\venv\lib\site-packages\ipykernel_launcher.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   """
# Epoch 1/50
# 94/94 [==============================] - 607s 6s/step - loss: 0.1967 - tp: 1.0000 - fp: 60.0000 - tn: 3006.0000 - fn: 133.0000 - accuracy: 0.9397 - precision: 0.0164 - recall: 0.0075 - auc: 0.6019 - prc: 0.0555 - val_loss: 0.1604 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8022 - val_prc: 0.1339
# Epoch 2/50
# 94/94 [==============================] - 524s 6s/step - loss: 0.1558 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2868.0000 - fn: 124.0000 - accuracy: 0.9586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7512 - prc: 0.1080 - val_loss: 0.1681 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7964 - val_prc: 0.1911
# Epoch 3/50
# 94/94 [==============================] - 577s 6s/step - loss: 0.1526 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2868.0000 - fn: 124.0000 - accuracy: 0.9586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7798 - prc: 0.1220 - val_loss: 0.1502 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8250 - val_prc: 0.2464
# Epoch 4/50
# 94/94 [==============================] - 625s 7s/step - loss: 0.1468 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2868.0000 - fn: 124.0000 - accuracy: 0.9586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7961 - prc: 0.1883 - val_loss: 0.1372 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8778 - val_prc: 0.3283
# Epoch 5/50
# 94/94 [==============================] - 617s 7s/step - loss: 0.1477 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2868.0000 - fn: 124.0000 - accuracy: 0.9586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.7986 - prc: 0.1597 - val_loss: 0.1523 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8386 - val_prc: 0.2767
# Epoch 6/50
# 94/94 [==============================] - 642s 7s/step - loss: 0.1417 - tp: 0.0000e+00 - fp: 0.0000e+00 - tn: 2868.0000 - fn: 124.0000 - accuracy: 0.9586 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8284 - prc: 0.1730 - val_loss: 0.1470 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8420 - val_prc: 0.2273
# Epoch 7/50
# 94/94 [==============================] - 634s 7s/step - loss: 0.1381 - tp: 1.0000 - fp: 3.0000 - tn: 2865.0000 - fn: 123.0000 - accuracy: 0.9579 - precision: 0.2500 - recall: 0.0081 - auc: 0.8393 - prc: 0.1969 - val_loss: 0.1394 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8638 - val_prc: 0.3307
# Epoch 8/50
# 94/94 [==============================] - 648s 7s/step - loss: 0.1350 - tp: 4.0000 - fp: 5.0000 - tn: 2863.0000 - fn: 120.0000 - accuracy: 0.9582 - precision: 0.4444 - recall: 0.0323 - auc: 0.8485 - prc: 0.2364 - val_loss: 0.1462 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8923 - val_prc: 0.3201
# Epoch 9/50
# 94/94 [==============================] - 636s 7s/step - loss: 0.1386 - tp: 0.0000e+00 - fp: 1.0000 - tn: 2867.0000 - fn: 124.0000 - accuracy: 0.9582 - precision: 0.0000e+00 - recall: 0.0000e+00 - auc: 0.8472 - prc: 0.1822 - val_loss: 0.1305 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8736 - val_prc: 0.3878
# Epoch 10/50
# 94/94 [==============================] - 637s 7s/step - loss: 0.1303 - tp: 4.0000 - fp: 1.0000 - tn: 2867.0000 - fn: 120.0000 - accuracy: 0.9596 - precision: 0.8000 - recall: 0.0323 - auc: 0.8621 - prc: 0.2970 - val_loss: 0.1214 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9096 - val_prc: 0.4394
# Epoch 11/50
# 94/94 [==============================] - 649s 7s/step - loss: 0.1292 - tp: 7.0000 - fp: 3.0000 - tn: 2865.0000 - fn: 117.0000 - accuracy: 0.9599 - precision: 0.7000 - recall: 0.0565 - auc: 0.8652 - prc: 0.2918 - val_loss: 0.1269 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 43.0000 - val_accuracy: 0.9559 - val_precision: 0.5000 - val_recall: 0.0227 - val_auc: 0.8934 - val_prc: 0.3970
# Epoch 12/50
# 94/94 [==============================] - 646s 7s/step - loss: 0.1308 - tp: 5.0000 - fp: 2.0000 - tn: 2866.0000 - fn: 119.0000 - accuracy: 0.9596 - precision: 0.7143 - recall: 0.0403 - auc: 0.8599 - prc: 0.2642 - val_loss: 0.1243 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9168 - val_prc: 0.5144
# Epoch 13/50
# 94/94 [==============================] - 681s 7s/step - loss: 0.1295 - tp: 13.0000 - fp: 3.0000 - tn: 2865.0000 - fn: 111.0000 - accuracy: 0.9619 - precision: 0.8125 - recall: 0.1048 - auc: 0.8610 - prc: 0.3128 - val_loss: 0.1284 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 44.0000 - val_accuracy: 0.9559 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8872 - val_prc: 0.4480
# Epoch 14/50
# 94/94 [==============================] - 675s 7s/step - loss: 0.1206 - tp: 13.0000 - fp: 5.0000 - tn: 2863.0000 - fn: 111.0000 - accuracy: 0.9612 - precision: 0.7222 - recall: 0.1048 - auc: 0.8961 - prc: 0.3554 - val_loss: 0.1213 - val_tp: 5.0000 - val_fp: 2.0000 - val_tn: 952.0000 - val_fn: 39.0000 - val_accuracy: 0.9589 - val_precision: 0.7143 - val_recall: 0.1136 - val_auc: 0.8907 - val_prc: 0.4564
# Epoch 15/50
# 94/94 [==============================] - 675s 7s/step - loss: 0.1210 - tp: 13.0000 - fp: 10.0000 - tn: 2858.0000 - fn: 111.0000 - accuracy: 0.9596 - precision: 0.5652 - recall: 0.1048 - auc: 0.8927 - prc: 0.3464 - val_loss: 0.1133 - val_tp: 6.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 38.0000 - val_accuracy: 0.9589 - val_precision: 0.6667 - val_recall: 0.1364 - val_auc: 0.9224 - val_prc: 0.4544
# Epoch 16/50
# 94/94 [==============================] - 665s 7s/step - loss: 0.1265 - tp: 17.0000 - fp: 7.0000 - tn: 2861.0000 - fn: 107.0000 - accuracy: 0.9619 - precision: 0.7083 - recall: 0.1371 - auc: 0.8740 - prc: 0.3307 - val_loss: 0.1185 - val_tp: 5.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 39.0000 - val_accuracy: 0.9599 - val_precision: 0.8333 - val_recall: 0.1136 - val_auc: 0.9126 - val_prc: 0.4445
# Epoch 17/50
# 94/94 [==============================] - 667s 7s/step - loss: 0.1150 - tp: 22.0000 - fp: 6.0000 - tn: 2862.0000 - fn: 102.0000 - accuracy: 0.9639 - precision: 0.7857 - recall: 0.1774 - auc: 0.9037 - prc: 0.4252 - val_loss: 0.1135 - val_tp: 13.0000 - val_fp: 4.0000 - val_tn: 950.0000 - val_fn: 31.0000 - val_accuracy: 0.9649 - val_precision: 0.7647 - val_recall: 0.2955 - val_auc: 0.9067 - val_prc: 0.4973
# Epoch 18/50
# 94/94 [==============================] - 659s 7s/step - loss: 0.1205 - tp: 18.0000 - fp: 14.0000 - tn: 2854.0000 - fn: 106.0000 - accuracy: 0.9599 - precision: 0.5625 - recall: 0.1452 - auc: 0.8886 - prc: 0.3435 - val_loss: 0.1252 - val_tp: 7.0000 - val_fp: 5.0000 - val_tn: 949.0000 - val_fn: 37.0000 - val_accuracy: 0.9579 - val_precision: 0.5833 - val_recall: 0.1591 - val_auc: 0.9318 - val_prc: 0.4578
# Epoch 19/50
# 94/94 [==============================] - 657s 7s/step - loss: 0.1171 - tp: 18.0000 - fp: 8.0000 - tn: 2860.0000 - fn: 106.0000 - accuracy: 0.9619 - precision: 0.6923 - recall: 0.1452 - auc: 0.8960 - prc: 0.3948 - val_loss: 0.1185 - val_tp: 17.0000 - val_fp: 16.0000 - val_tn: 938.0000 - val_fn: 27.0000 - val_accuracy: 0.9569 - val_precision: 0.5152 - val_recall: 0.3864 - val_auc: 0.9291 - val_prc: 0.4456
# Epoch 20/50
# 94/94 [==============================] - 676s 7s/step - loss: 0.1174 - tp: 19.0000 - fp: 11.0000 - tn: 2857.0000 - fn: 105.0000 - accuracy: 0.9612 - precision: 0.6333 - recall: 0.1532 - auc: 0.8944 - prc: 0.3762 - val_loss: 0.1128 - val_tp: 4.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 40.0000 - val_accuracy: 0.9569 - val_precision: 0.5714 - val_recall: 0.0909 - val_auc: 0.9320 - val_prc: 0.4789
# Epoch 21/50
# 94/94 [==============================] - 671s 7s/step - loss: 0.1129 - tp: 14.0000 - fp: 9.0000 - tn: 2859.0000 - fn: 110.0000 - accuracy: 0.9602 - precision: 0.6087 - recall: 0.1129 - auc: 0.9162 - prc: 0.3857 - val_loss: 0.1251 - val_tp: 10.0000 - val_fp: 6.0000 - val_tn: 948.0000 - val_fn: 34.0000 - val_accuracy: 0.9599 - val_precision: 0.6250 - val_recall: 0.2273 - val_auc: 0.8946 - val_prc: 0.4238
# Epoch 22/50
# 94/94 [==============================] - 636s 7s/step - loss: 0.1178 - tp: 14.0000 - fp: 10.0000 - tn: 2858.0000 - fn: 110.0000 - accuracy: 0.9599 - precision: 0.5833 - recall: 0.1129 - auc: 0.8986 - prc: 0.3681 - val_loss: 0.1159 - val_tp: 5.0000 - val_fp: 2.0000 - val_tn: 952.0000 - val_fn: 39.0000 - val_accuracy: 0.9589 - val_precision: 0.7143 - val_recall: 0.1136 - val_auc: 0.9073 - val_prc: 0.4898
# Epoch 23/50
# 94/94 [==============================] - 682s 7s/step - loss: 0.1093 - tp: 18.0000 - fp: 17.0000 - tn: 2851.0000 - fn: 106.0000 - accuracy: 0.9589 - precision: 0.5143 - recall: 0.1452 - auc: 0.9250 - prc: 0.3915 - val_loss: 0.1165 - val_tp: 7.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 37.0000 - val_accuracy: 0.9599 - val_precision: 0.7000 - val_recall: 0.1591 - val_auc: 0.9107 - val_prc: 0.4201
# Epoch 24/50
# 94/94 [==============================] - 676s 7s/step - loss: 0.1141 - tp: 17.0000 - fp: 9.0000 - tn: 2859.0000 - fn: 107.0000 - accuracy: 0.9612 - precision: 0.6538 - recall: 0.1371 - auc: 0.9042 - prc: 0.3961 - val_loss: 0.1156 - val_tp: 7.0000 - val_fp: 5.0000 - val_tn: 949.0000 - val_fn: 37.0000 - val_accuracy: 0.9579 - val_precision: 0.5833 - val_recall: 0.1591 - val_auc: 0.9094 - val_prc: 0.4377
# Epoch 25/50
# 94/94 [==============================] - 672s 7s/step - loss: 0.1100 - tp: 30.0000 - fp: 21.0000 - tn: 2847.0000 - fn: 94.0000 - accuracy: 0.9616 - precision: 0.5882 - recall: 0.2419 - auc: 0.9154 - prc: 0.4237 - val_loss: 0.1112 - val_tp: 5.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 39.0000 - val_accuracy: 0.9579 - val_precision: 0.6250 - val_recall: 0.1136 - val_auc: 0.9166 - val_prc: 0.4979
# Epoch 26/50
# 94/94 [==============================] - 664s 7s/step - loss: 0.1141 - tp: 13.0000 - fp: 11.0000 - tn: 2857.0000 - fn: 111.0000 - accuracy: 0.9592 - precision: 0.5417 - recall: 0.1048 - auc: 0.9074 - prc: 0.3534 - val_loss: 0.1106 - val_tp: 12.0000 - val_fp: 5.0000 - val_tn: 949.0000 - val_fn: 32.0000 - val_accuracy: 0.9629 - val_precision: 0.7059 - val_recall: 0.2727 - val_auc: 0.9149 - val_prc: 0.5075
# Epoch 27/50
# 94/94 [==============================] - 666s 7s/step - loss: 0.1088 - tp: 16.0000 - fp: 20.0000 - tn: 2848.0000 - fn: 108.0000 - accuracy: 0.9572 - precision: 0.4444 - recall: 0.1290 - auc: 0.9218 - prc: 0.3903 - val_loss: 0.1089 - val_tp: 6.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 38.0000 - val_accuracy: 0.9589 - val_precision: 0.6667 - val_recall: 0.1364 - val_auc: 0.9240 - val_prc: 0.5046
# Epoch 28/50
# 94/94 [==============================] - 680s 7s/step - loss: 0.1169 - tp: 14.0000 - fp: 7.0000 - tn: 2861.0000 - fn: 110.0000 - accuracy: 0.9609 - precision: 0.6667 - recall: 0.1129 - auc: 0.8935 - prc: 0.4024 - val_loss: 0.1063 - val_tp: 5.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 39.0000 - val_accuracy: 0.9579 - val_precision: 0.6250 - val_recall: 0.1136 - val_auc: 0.9337 - val_prc: 0.5079
# Epoch 29/50
# 94/94 [==============================] - 675s 7s/step - loss: 0.1112 - tp: 14.0000 - fp: 12.0000 - tn: 2856.0000 - fn: 110.0000 - accuracy: 0.9592 - precision: 0.5385 - recall: 0.1129 - auc: 0.9141 - prc: 0.4028 - val_loss: 0.1578 - val_tp: 1.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 43.0000 - val_accuracy: 0.9559 - val_precision: 0.5000 - val_recall: 0.0227 - val_auc: 0.8721 - val_prc: 0.3847
# Epoch 30/50
# 94/94 [==============================] - 670s 7s/step - loss: 0.1169 - tp: 18.0000 - fp: 13.0000 - tn: 2855.0000 - fn: 106.0000 - accuracy: 0.9602 - precision: 0.5806 - recall: 0.1452 - auc: 0.9005 - prc: 0.3708 - val_loss: 0.1157 - val_tp: 6.0000 - val_fp: 5.0000 - val_tn: 949.0000 - val_fn: 38.0000 - val_accuracy: 0.9569 - val_precision: 0.5455 - val_recall: 0.1364 - val_auc: 0.9436 - val_prc: 0.4636
# Epoch 31/50
# 94/94 [==============================] - 662s 7s/step - loss: 0.1169 - tp: 17.0000 - fp: 6.0000 - tn: 2862.0000 - fn: 107.0000 - accuracy: 0.9622 - precision: 0.7391 - recall: 0.1371 - auc: 0.8985 - prc: 0.4008 - val_loss: 0.1135 - val_tp: 14.0000 - val_fp: 11.0000 - val_tn: 943.0000 - val_fn: 30.0000 - val_accuracy: 0.9589 - val_precision: 0.5600 - val_recall: 0.3182 - val_auc: 0.9285 - val_prc: 0.5019
# Epoch 32/50
# 94/94 [==============================] - 691s 7s/step - loss: 0.1103 - tp: 23.0000 - fp: 13.0000 - tn: 2855.0000 - fn: 101.0000 - accuracy: 0.9619 - precision: 0.6389 - recall: 0.1855 - auc: 0.9127 - prc: 0.4266 - val_loss: 0.1102 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 40.0000 - val_accuracy: 0.9599 - val_precision: 1.0000 - val_recall: 0.0909 - val_auc: 0.9234 - val_prc: 0.5486
# Epoch 33/50
# 94/94 [==============================] - 672s 7s/step - loss: 0.1086 - tp: 24.0000 - fp: 12.0000 - tn: 2856.0000 - fn: 100.0000 - accuracy: 0.9626 - precision: 0.6667 - recall: 0.1935 - auc: 0.9193 - prc: 0.4205 - val_loss: 0.1122 - val_tp: 10.0000 - val_fp: 2.0000 - val_tn: 952.0000 - val_fn: 34.0000 - val_accuracy: 0.9639 - val_precision: 0.8333 - val_recall: 0.2273 - val_auc: 0.9244 - val_prc: 0.4560
# Epoch 34/50
# 94/94 [==============================] - 665s 7s/step - loss: 0.1088 - tp: 19.0000 - fp: 10.0000 - tn: 2858.0000 - fn: 105.0000 - accuracy: 0.9616 - precision: 0.6552 - recall: 0.1532 - auc: 0.9192 - prc: 0.4179 - val_loss: 0.1244 - val_tp: 6.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 38.0000 - val_accuracy: 0.9589 - val_precision: 0.6667 - val_recall: 0.1364 - val_auc: 0.9009 - val_prc: 0.3766
# Epoch 35/50
# 94/94 [==============================] - 676s 7s/step - loss: 0.1069 - tp: 17.0000 - fp: 14.0000 - tn: 2854.0000 - fn: 107.0000 - accuracy: 0.9596 - precision: 0.5484 - recall: 0.1371 - auc: 0.9249 - prc: 0.4055 - val_loss: 0.1213 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 40.0000 - val_accuracy: 0.9599 - val_precision: 1.0000 - val_recall: 0.0909 - val_auc: 0.9142 - val_prc: 0.4753
# Epoch 36/50
# 94/94 [==============================] - 657s 7s/step - loss: 0.1156 - tp: 22.0000 - fp: 7.0000 - tn: 2861.0000 - fn: 102.0000 - accuracy: 0.9636 - precision: 0.7586 - recall: 0.1774 - auc: 0.8931 - prc: 0.4083 - val_loss: 0.1217 - val_tp: 12.0000 - val_fp: 7.0000 - val_tn: 947.0000 - val_fn: 32.0000 - val_accuracy: 0.9609 - val_precision: 0.6316 - val_recall: 0.2727 - val_auc: 0.8877 - val_prc: 0.4804
# Epoch 37/50
# 94/94 [==============================] - 657s 7s/step - loss: 0.1063 - tp: 21.0000 - fp: 10.0000 - tn: 2858.0000 - fn: 103.0000 - accuracy: 0.9622 - precision: 0.6774 - recall: 0.1694 - auc: 0.9204 - prc: 0.4579 - val_loss: 0.1082 - val_tp: 14.0000 - val_fp: 5.0000 - val_tn: 949.0000 - val_fn: 30.0000 - val_accuracy: 0.9649 - val_precision: 0.7368 - val_recall: 0.3182 - val_auc: 0.9256 - val_prc: 0.4950
# Epoch 38/50
# 94/94 [==============================] - 642s 7s/step - loss: 0.1032 - tp: 28.0000 - fp: 8.0000 - tn: 2860.0000 - fn: 96.0000 - accuracy: 0.9652 - precision: 0.7778 - recall: 0.2258 - auc: 0.9294 - prc: 0.4844 - val_loss: 0.1335 - val_tp: 4.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 40.0000 - val_accuracy: 0.9589 - val_precision: 0.8000 - val_recall: 0.0909 - val_auc: 0.8911 - val_prc: 0.4751
# Epoch 39/50
# 94/94 [==============================] - 672s 7s/step - loss: 0.1098 - tp: 21.0000 - fp: 8.0000 - tn: 2860.0000 - fn: 103.0000 - accuracy: 0.9629 - precision: 0.7241 - recall: 0.1694 - auc: 0.9047 - prc: 0.4458 - val_loss: 0.1346 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 42.0000 - val_accuracy: 0.9569 - val_precision: 0.6667 - val_recall: 0.0455 - val_auc: 0.8817 - val_prc: 0.4447
# Epoch 40/50
# 94/94 [==============================] - 673s 7s/step - loss: 0.1043 - tp: 24.0000 - fp: 9.0000 - tn: 2859.0000 - fn: 100.0000 - accuracy: 0.9636 - precision: 0.7273 - recall: 0.1935 - auc: 0.9274 - prc: 0.4601 - val_loss: 0.1160 - val_tp: 23.0000 - val_fp: 22.0000 - val_tn: 932.0000 - val_fn: 21.0000 - val_accuracy: 0.9569 - val_precision: 0.5111 - val_recall: 0.5227 - val_auc: 0.9381 - val_prc: 0.5329
# Epoch 41/50
# 94/94 [==============================] - 652s 7s/step - loss: 0.1092 - tp: 33.0000 - fp: 17.0000 - tn: 2851.0000 - fn: 91.0000 - accuracy: 0.9639 - precision: 0.6600 - recall: 0.2661 - auc: 0.9062 - prc: 0.4312 - val_loss: 0.1234 - val_tp: 2.0000 - val_fp: 1.0000 - val_tn: 953.0000 - val_fn: 42.0000 - val_accuracy: 0.9569 - val_precision: 0.6667 - val_recall: 0.0455 - val_auc: 0.8946 - val_prc: 0.4671
# Epoch 42/50
# 94/94 [==============================] - 666s 7s/step - loss: 0.1048 - tp: 28.0000 - fp: 20.0000 - tn: 2848.0000 - fn: 96.0000 - accuracy: 0.9612 - precision: 0.5833 - recall: 0.2258 - auc: 0.9236 - prc: 0.4549 - val_loss: 0.1160 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 36.0000 - val_accuracy: 0.9609 - val_precision: 0.7273 - val_recall: 0.1818 - val_auc: 0.9006 - val_prc: 0.4758
# Epoch 43/50
# 94/94 [==============================] - 671s 7s/step - loss: 0.1022 - tp: 28.0000 - fp: 14.0000 - tn: 2854.0000 - fn: 96.0000 - accuracy: 0.9632 - precision: 0.6667 - recall: 0.2258 - auc: 0.9272 - prc: 0.4807 - val_loss: 0.1255 - val_tp: 19.0000 - val_fp: 16.0000 - val_tn: 938.0000 - val_fn: 25.0000 - val_accuracy: 0.9589 - val_precision: 0.5429 - val_recall: 0.4318 - val_auc: 0.9304 - val_prc: 0.4984
# Epoch 44/50
# 94/94 [==============================] - 661s 7s/step - loss: 0.1052 - tp: 21.0000 - fp: 6.0000 - tn: 2862.0000 - fn: 103.0000 - accuracy: 0.9636 - precision: 0.7778 - recall: 0.1694 - auc: 0.9243 - prc: 0.4656 - val_loss: 0.1017 - val_tp: 12.0000 - val_fp: 3.0000 - val_tn: 951.0000 - val_fn: 32.0000 - val_accuracy: 0.9649 - val_precision: 0.8000 - val_recall: 0.2727 - val_auc: 0.9282 - val_prc: 0.5581
# Epoch 45/50
# 94/94 [==============================] - 671s 7s/step - loss: 0.0944 - tp: 31.0000 - fp: 17.0000 - tn: 2851.0000 - fn: 93.0000 - accuracy: 0.9632 - precision: 0.6458 - recall: 0.2500 - auc: 0.9384 - prc: 0.5279 - val_loss: 0.1105 - val_tp: 14.0000 - val_fp: 10.0000 - val_tn: 944.0000 - val_fn: 30.0000 - val_accuracy: 0.9599 - val_precision: 0.5833 - val_recall: 0.3182 - val_auc: 0.9243 - val_prc: 0.4954
# Epoch 46/50
# 94/94 [==============================] - 675s 7s/step - loss: 0.0948 - tp: 35.0000 - fp: 18.0000 - tn: 2850.0000 - fn: 89.0000 - accuracy: 0.9642 - precision: 0.6604 - recall: 0.2823 - auc: 0.9434 - prc: 0.5236 - val_loss: 0.1204 - val_tp: 11.0000 - val_fp: 4.0000 - val_tn: 950.0000 - val_fn: 33.0000 - val_accuracy: 0.9629 - val_precision: 0.7333 - val_recall: 0.2500 - val_auc: 0.9094 - val_prc: 0.4801
# Epoch 47/50
# 94/94 [==============================] - 673s 7s/step - loss: 0.1022 - tp: 25.0000 - fp: 18.0000 - tn: 2850.0000 - fn: 99.0000 - accuracy: 0.9609 - precision: 0.5814 - recall: 0.2016 - auc: 0.9287 - prc: 0.4446 - val_loss: 0.1182 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 954.0000 - val_fn: 39.0000 - val_accuracy: 0.9609 - val_precision: 1.0000 - val_recall: 0.1136 - val_auc: 0.8990 - val_prc: 0.5336
# Epoch 48/50
# 94/94 [==============================] - 658s 7s/step - loss: 0.1044 - tp: 21.0000 - fp: 16.0000 - tn: 2852.0000 - fn: 103.0000 - accuracy: 0.9602 - precision: 0.5676 - recall: 0.1694 - auc: 0.9331 - prc: 0.4313 - val_loss: 0.1289 - val_tp: 2.0000 - val_fp: 2.0000 - val_tn: 952.0000 - val_fn: 42.0000 - val_accuracy: 0.9559 - val_precision: 0.5000 - val_recall: 0.0455 - val_auc: 0.8873 - val_prc: 0.4341
# Epoch 49/50
# 94/94 [==============================] - 670s 7s/step - loss: 0.1086 - tp: 21.0000 - fp: 9.0000 - tn: 2859.0000 - fn: 103.0000 - accuracy: 0.9626 - precision: 0.7000 - recall: 0.1694 - auc: 0.9150 - prc: 0.4679 - val_loss: 0.1112 - val_tp: 6.0000 - val_fp: 2.0000 - val_tn: 952.0000 - val_fn: 38.0000 - val_accuracy: 0.9599 - val_precision: 0.7500 - val_recall: 0.1364 - val_auc: 0.9193 - val_prc: 0.5250
# Epoch 50/50
# 94/94 [==============================] - 666s 7s/step - loss: 0.1001 - tp: 29.0000 - fp: 13.0000 - tn: 2855.0000 - fn: 95.0000 - accuracy: 0.9639 - precision: 0.6905 - recall: 0.2339 - auc: 0.9294 - prc: 0.5263 - val_loss: 0.1187 - val_tp: 10.0000 - val_fp: 4.0000 - val_tn: 950.0000 - val_fn: 34.0000 - val_accuracy: 0.9619 - val_precision: 0.7143 - val_recall: 0.2273 - val_auc: 0.8863 - val_prc: 0.5209

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.save('./cnn_50_epoch_more_metrics')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18808\709207326.py in <module>
# ----> 1 model.save('./cnn_50_epoch_more_metrics')
#
# c:\y\HARP_3_7\venv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\y\HARP_3_7\venv\lib\site-packages\tensorflow\python\lib\io\file_io.py in recursive_create_dir_v2(path)
#     509     errors.OpError: If the operation fails.
#     510   """
# --> 511   _pywrap_file_io.RecursivelyCreateDir(compat.path_to_bytes(path))
#     512
#     513
#
# InvalidArgumentError: Failed to create a directory: ./cnn_50_epoch_more_metrics; Invalid argument

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (12, 10)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']



def plot_metrics(history):
  metrics = ['loss', 'prc', 'precision', 'recall']
  for n, metric in enumerate(metrics):
    name = metric.replace("_"," ").capitalize()
    plt.subplot(2,2,n+1)
    plt.plot(history.epoch, history.history[metric], color=colors[0], label='Train')
    plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
    plt.xlabel('Epoch')
    plt.ylabel(name)
    if metric == 'loss':
      plt.ylim([0, plt.ylim()[1]])
    elif metric == 'auc':
      plt.ylim([0.8,1])
    else:
      plt.ylim([0,1])

    plt.legend()

plot_metrics(history)
